# %%
import pandas as pd
from bioinfokit import analys, visuz

# %%
df = pd.read_csv('/mnt/sdb1/Project_Sieja_MCLR_52/2_pipeline/7_counting_transcripts/noncoding_known/up_down_known_DESEQ_9d_with_names.csv')

# %%
df.head()
# Out:
#                           ID    PBS_1d_1    PBS_1d_2    PBS_1d_3    PBS_1d_4  \
# 0  TRINITY_DN100157_c0_g1_i2   35.356326   58.519385   45.311356   24.782619
# 1  TRINITY_DN102574_c4_g1_i2   24.383673   22.948778   57.897844   14.161497
# 2  TRINITY_DN103080_c3_g1_i1  366.974285  298.334120  349.904362  400.062284
# 3  TRINITY_DN105022_c3_g1_i4   48.767347   47.044996   79.294873   25.962744
# 4  TRINITY_DN105450_c0_g4_i1  385.262040  236.372418  356.197606  486.211389
#
#       MC_9d_1     MC_9d_2     MC_9d_3          padj  log2FoldChange  \
# 0    0.767530    0.000000    0.000000  1.051577e-10       -7.267013
# 1    0.000000    0.000000    0.000000  2.108364e-07       -7.769064
# 2  128.945048  116.229800  119.079449  4.761733e-08       -1.543054
# 3    0.000000    1.490126    6.456115  7.102511e-05       -4.230326
# 4   35.306382   27.567324   56.670340  9.436692e-11       -3.198043
#
#          pvalue  foldChange  log10padj         name       id
# 0  3.115582e-12    0.006492   9.978159    Vax2os1_3  RF02272
# 1  1.335038e-08    0.004584   6.676054   KCNQ1OT1_1  RF01946
# 2  2.486510e-09    0.343158   7.322235  RFPL3-AS1_1  RF02171
# 3  8.921382e-06    0.053278   4.148588        bxd_3  RF01931
# 4  2.750917e-12    0.108967  10.025180   KCNQ1OT1_2  RF01947

# %%
#visuz.gene_exp.volcano(d=df, lfc='log2FoldChange', pv='padj', geneid='name', genenames=({"MALAT1":"MALAT1", "HOTAIR_1":"HOTAIR", "HOTTIP_2":"HOTTIP", "HULC":"HULC"}), gstyle=1, valpha=0.5)
visuz.gene_exp.volcano(d=df, lfc='log2FoldChange', pv='padj', geneid='name', gstyle=1, valpha=0.5)
