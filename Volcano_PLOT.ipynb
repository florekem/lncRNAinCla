# %%
import pandas as pd
from bioinfokit import analys, visuz

# %%
#KNOWN

# %%
df = pd.read_csv('/mnt/sdb1/Project_Sieja_MCLR_52/2_pipeline/7_counting_transcripts/noncoding_known/up_down_known_DESEQ_1d_with_names_lnc_only.csv')

# %%
df.head()
# Out:
#                           ID    PBS_1d_1    PBS_1d_2    PBS_1d_3    PBS_1d_4  \
# 0  TRINITY_DN105450_c0_g4_i1  309.362414  187.640144  281.594567  392.272092
# 1   TRINITY_DN69529_c0_g1_i1   23.495880   19.128364   63.682164  135.200575
# 2   TRINITY_DN77176_c0_g2_i1   93.004523   71.048210   91.543110   37.132552
# 3   TRINITY_DN86560_c9_g2_i3   64.613669   71.959084   91.543110   43.797369
# 4  TRINITY_DN88980_c18_g1_i3   46.991759   46.454599   30.846048   71.408755
#
#       MC_1d_1     MC_1d_2     MC_1d_3          padj  log2FoldChange  \
# 0   13.312092   27.476768    0.000000  7.123849e-06       -4.402864
# 1    0.000000    1.665259    0.000000  7.363374e-06       -6.580705
# 2  210.945466  865.934496  312.526216  5.384898e-05        2.663142
# 3   17.408121    9.991552   10.534592  5.469524e-05       -2.429397
# 4    0.000000    1.665259    0.000000  1.281560e-09       -6.246925
#
#          pvalue  foldChange  log10padj        name       id
# 0  2.269814e-07    0.047272   5.147285  KCNQ1OT1_2  RF01947
# 1  2.369689e-07    0.010447   5.132923   Six3os1_2  RF02247
# 2  2.265770e-06    6.334112   4.268823    HOTTIP_3  RF02042
# 3  2.309716e-06    0.185643   4.262050   Six3os1_2  RF02247
# 4  1.758372e-11    0.013167   8.892261      TUG1_2  RF01883

# %%
#visuz.gene_exp.volcano(d=df, lfc='log2FoldChange', pv='padj', geneid='name', genenames=({"MALAT1":"MALAT1", "HOTAIR_1":"HOTAIR", "HOTTIP_2":"HOTTIP", "HULC":"HULC"}), gstyle=1, valpha=0.5)
visuz.gene_exp.volcano(d=df, lfc='log2FoldChange', pv='padj', geneid='name', gstyle=1, valpha=0.5)

# %%
#NOVEL

# %%
path = '/mnt/sdb1/Project_Sieja_MCLR_52/2_pipeline/7_counting_transcripts/noncoding_novel/'
df = pd.read_csv(path+'TRUE_NOVEL_ncRNA_1d_after_deseq_w_trinity_names.csv')
df6 = pd.read_csv(path+'TRUE_NOVEL_ncRNA_6d_after_deseq_w_trinity_names.csv')
df9 = pd.read_csv(path+'TRUE_NOVEL_ncRNA_9d_after_deseq_w_trinity_names.csv')

# %%
visuz.gene_exp.volcano(d=df9, lfc='log2FoldChange', pv='padj', geneid='name', gstyle=1, valpha=0.5)
